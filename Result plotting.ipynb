# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [20, 10]
plt.rcParams.update({'font.size': 22})

# %%
w = pd.read_csv("/mnt/c/Users/Ruben/Downloads/run_unet-water-final.csv")
wf = pd.read_csv("/mnt/c/Users/Ruben/Downloads/run_unet-water-final-finetune.csv")
w = w.append(wf, ignore_index=True)

b = pd.read_csv("/mnt/c/Users/Ruben/Downloads/run_unet-buildings-final.csv")
bf = pd.read_csv("/mnt/c/Users/Ruben/Downloads/run_unet-buildings-final-finetune.csv")
b = b.append(bf, ignore_index=True)

v = pd.read_csv("/mnt/c/Users/Ruben/Downloads/run_unet-vegetation-final.csv")
vf = pd.read_csv("/mnt/c/Users/Ruben/Downloads/run_unet-vegetation-final-finetune.csv")
v = v.append(vf, ignore_index=True)

r = pd.read_csv("/mnt/c/Users/Ruben/Downloads/run_unet-roads-final.csv")
rf = pd.read_csv("/mnt/c/Users/Ruben/Downloads/run_unet-roads-final-finetune.csv")
r = r.append(rf, ignore_index=True)
#plt.hlines(df.loc[df['Value'].idxmax()]['Value'], 0, 70, linestyles='dashed')
plt.xlabel('Epoch')
plt.ylabel('Batch mIOU')
plt.grid(True)
plt.plot(w['Value'], label='Water')
plt.plot(b['Value'], label='Buildings')
plt.plot(v['Value'], label='Vegetation')
plt.plot(r['Value'], label='Roads')
leg = plt.legend(loc=4)
leg.get_frame().set_alpha(0.5)
